# %% [markdown]
# # Evaluate MSMS-Set Ouputs & Generate Final Observation Table

# %%
import pandas as pd
import glob
import os

from ipywidgets import widgets, interact, interactive, interactive_output, Layout, Style, HBox, VBox
from IPython.display import clear_output
import shutil

# %%
class PDF(object):
    def __init__(self, pdf, size=(200,200)):
        self.pdf = pdf
        self.size = size

    def _repr_html_(self):
        return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

    def _repr_latex_(self):
        return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %% [markdown]
# ## Rerun Notebook From Here with Other Chromatography if Needed

# %%
chromatography = 'c18' #'hilic' or 'c18'

# %%
msms_set_output_dir = 'downloads/plant_standards_diagnostic_plots_{chromatography}'.format(chromatography=chromatography)
msms_set_output_good_dir = 'downloads/plant_standards_diagnostic_plots_{chromatography}/good'.format(chromatography=chromatography)
msms_set_output_ambiguous_dir = 'downloads/plant_standards_diagnostic_plots_{chromatography}/ambiguous'.format(chromatography=chromatography)

output_df = pd.read_csv(os.path.join(msms_set_output_dir, 'diagnostic_peakheight_and_centroids.csv'))

# %%
output_df['filter_override'] = 'False'
output_df['group'] = ''
for idx, row in output_df.iterrows():
    output_df.loc[idx, 'group'] = str(row['compound_name']).split('-')[0]

# %%
output_df.head()
# Out:
#                                        gnps_filename  seq  \
# 0  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 1  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 2  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 3  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 4  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
#
#                                        compound_name  moleculemass instrument  \
# 0          Indole3AceticAcid-IAA-CE102040-10ugmL-M+H    176.070605   Orbitrap
# 1          Indole3AceticAcid-IAA-CE205060-10ugmL-M+H    176.070605   Orbitrap
# 2          Indole3AceticAcid-IAA-CE102040-10ugmL-M-H    174.056053   Orbitrap
# 3          Indole3AceticAcid-IAA-CE205060-10ugmL-M-H    174.056053   Orbitrap
# 4  MethylIndole3AceticAcid-MeIAA-CE102040-10ugmL-M+H    190.086255   Orbitrap
#
#   ionsource  extractscan                        smiles  \
# 0       ESI         1605  C1=CC=C2C(=C1)C(=CN2)CC(=O)O
# 1       ESI         1616  C1=CC=C2C(=C1)C(=CN2)CC(=O)O
# 2       ESI         1431  C1=CC=C2C(=C1)C(=CN2)CC(=O)O
# 3       ESI         1425  C1=CC=C2C(=C1)C(=CN2)CC(=O)O
# 4       ESI         2009   CN1C=C(C2=CC=CC=C21)CC(=O)O
#
#                                                inchi  inchiaux  ...  \
# 0  InChI=1S/C10H9NO2/c12-10(13)5-7-6-11-9-4-2-1-3...       NaN  ...
# 1  InChI=1S/C10H9NO2/c12-10(13)5-7-6-11-9-4-2-1-3...       NaN  ...
# 2  InChI=1S/C10H9NO2/c12-10(13)5-7-6-11-9-4-2-1-3...       NaN  ...
# 3  InChI=1S/C10H9NO2/c12-10(13)5-7-6-11-9-4-2-1-3...       NaN  ...
# 4  InChI=1S/C11H11NO2/c1-12-7-8(6-11(13)14)9-4-2-...       NaN  ...
#
#                                           label_msms  \
# 0          Indole3AceticAcid-IAA-CE102040-10ugmL-M+H
# 1          Indole3AceticAcid-IAA-CE205060-10ugmL-M+H
# 2          Indole3AceticAcid-IAA-CE102040-10ugmL-M-H
# 3          Indole3AceticAcid-IAA-CE205060-10ugmL-M-H
# 4  MethylIndole3AceticAcid-MeIAA-CE102040-10ugmL-M+H
#
#                                              mz_msms  \
# 0  [52.788330078125 158.0602264404297 152.9387817...
# 1  [64.80179595947266 67.85295104980469 73.989204...
# 2  [53.343345642089844 174.8277130126953 174.0554...
# 3  [51.72565460205078 174.05535888671875 174.0198...
# 4  [51.7670783996582 190.08616638183594 179.40837...
#
#                                              rt_msms  \
# 0  [3.418055295944214 3.418055295944214 3.4180552...
# 1  [3.4225645065307617 3.4225645065307617 3.42256...
# 2  [3.42728328704834 3.42728328704834 3.427283287...
# 3  [3.4307847023010254 3.4307847023010254 3.43078...
# 4  [4.3192009925842285 4.3192009925842285 4.31920...
#
#                                               i_msms  \
# 0  [5327.37744140625 9308.4453125 14934.171875 88...
# 1  [12184.095703125 13163.990234375 13838.7490234...
# 2  [3477.192626953125 5028.0634765625 20162.87304...
# 3  [2994.330322265625 10627.1015625 5092.203125 6...
# 4  [6022.26171875 360872.21875 5924.5478515625 13...
#
#                                            label_eic  \
# 0          Indole3AceticAcid-IAA-CE102040-10ugmL-M+H
# 1          Indole3AceticAcid-IAA-CE205060-10ugmL-M+H
# 2          Indole3AceticAcid-IAA-CE102040-10ugmL-M-H
# 3          Indole3AceticAcid-IAA-CE205060-10ugmL-M-H
# 4  MethylIndole3AceticAcid-MeIAA-CE102040-10ugmL-M+H
#
#                                               rt_eic  \
# 0  [0.0038796914741396904 3.783439874649048 3.789...
# 1  [0.003922241274267435 3.7305870056152344 3.736...
# 2  [3.4027538299560547 3.5548195838928223 3.56185...
# 3  [3.403869867324829 3.572810411453247 3.5798604...
# 4  [0.05077457055449486 6.7230634689331055 6.7290...
#
#                                                i_eic  \
# 0  [6763.67822265625 29810.88671875 29780.0351562...
# 1  [6137.080078125 31885.2734375 41381.39453125 3...
# 2  [19462.630859375 9207.728515625 7721.6328125 8...
# 3  [7124.11669921875 7136.7978515625 7645.1728515...
# 4  [4262.34814453125 8485.923828125 8253.22167968...
#
#                                       in_feature_eic  filter_override  \
# 0  [False False False False False False False Fal...            False
# 1  [False False False False False False False Fal...            False
# 2  [True True True True True False False False Tr...            False
# 3  [True True True False False False False False ...            False
# 4  [False False False False False False False Fal...            False
#
#                      group
# 0        Indole3AceticAcid
# 1        Indole3AceticAcid
# 2        Indole3AceticAcid
# 3        Indole3AceticAcid
# 4  MethylIndole3AceticAcid
#
# [5 rows x 44 columns]

# %%
plot_files = glob.glob(os.path.join(msms_set_output_dir, '*.pdf'))

plot_filenames = []

for f in plot_files:
    plot_filenames.append(os.path.basename(f))
    
plot_filenames.append('')

# %%
plot_filenames[0]
# Out:
# 'Baicalein-3WL.pdf'

# %% [markdown]
# ## Adjust PDF Viewer Size

# %%
pdf_view_size = (2000, 800)
test_pdf = PDF(plot_files[0], size=pdf_view_size)
test_pdf
# Out:
# \includegraphics[width=1.0\textwidth]{downloads/plant_standards_diagnostic_plots_c18/Baicalein-3WL.pdf}

# %% [markdown]
# ## Filter Compounds into "Ambiguous" and "Good" Sets

# %%
compound_drop = widgets.Dropdown(
    options=plot_filenames,
    value='',
    description='Manual Select:',
    disabled=False, 
    style={'description_width':'initial'}
)

override_filter_button = widgets.ToggleButton(
    value=False,
    description='OVERRIDE FILTER',
    disabled=False,
    font_weight='bold',
    button_style='warning', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Don\'t use filtering logic for adducts, manually curate after',
    icon='ban' # (FontAwesome names without the `fa-` prefix)
)

good_button = button = widgets.Button(
    description='Good',
    disabled=False,
    style=dict(
    font_weight='bold',
    button_color='lightgreen')
)

ambiguous_button = button = widgets.Button(
    description='Ambiguous',
    disabled=False,
    style=dict(
    font_weight='bold',
    button_color='lightcoral')
)

def filter_adducts(idx, rt_diff_max = 0.2, intensity_min = 1000000):
    name = plot_filenames[idx].split('-')[0]
    adduct_df = output_df[output_df['group']==name]
    filtered_adduct_df = pd.DataFrame()
    
    peak_height_max = adduct_df['peak_height'].max()
    rt_set = adduct_df[adduct_df['peak_height']==peak_height_max]['rt_peak'].values[0]
    rt_min = rt_set  - rt_diff_max
    rt_max = rt_set + rt_diff_max
    
    for idx, row in adduct_df.iterrows():
        if row['rt_peak'] >= rt_min and row['rt_peak'] <= rt_max and row['peak_height'] >= intensity_min:
            filtered_adduct_df = pd.concat([filtered_adduct_df, output_df.iloc[[idx]]])
            
    return filtered_adduct_df

class Events:
    
    ind = -1
    ind_max = len(plot_files) - 1
    
    filtered_good_df = pd.DataFrame()
    ambiguous_df = pd.DataFrame()
    
    def good_button_click(self, event):
        with output:
            clear_output()
            
            if plot_files[self.ind] in plot_files and self.ind != -1:
                shutil.copyfile(plot_files[self.ind], os.path.join(msms_set_output_good_dir, plot_filenames[self.ind]))
                
                if override_filter_button.value == False:
                
                    filtered_adduct_df = filter_adducts(self.ind)
                    
                if override_filter_button.value == True:
                    
                    name = plot_filenames[self.ind].split('-')[0]
                    adduct_df = output_df[output_df['group']==name]
                    adduct_df = adduct_df.replace('False', 'True')
                    
                    filtered_adduct_df = adduct_df
                
                self.filtered_good_df = pd.concat([self.filtered_good_df, filtered_adduct_df])
            
            if self.ind < self.ind_max:
                self.ind += 1
                pdf = PDF(plot_files[self.ind], size=pdf_view_size)
                
                return display(pdf), print(self.ind)
            if self.ind == self.ind_max:
                return print('Compound Evaluation Complete!')
            
    def ambiguous_button_click(self, event):
        with output:
            clear_output()
            
            if plot_files[self.ind] in plot_files and self.ind != -1:
                shutil.copyfile(plot_files[self.ind], os.path.join(msms_set_output_ambiguous_dir, plot_filenames[self.ind]))
                
                name = plot_filenames[self.ind].split('-')[0]
                adduct_df = output_df[output_df['group']==name]
                self.ambiguous_df = pd.concat([self.ambiguous_df, adduct_df])
                
            if self.ind < self.ind_max:
                self.ind += 1
                pdf = PDF(plot_files[self.ind], size=pdf_view_size)
                return display(pdf), print(self.ind)
            if self.ind == self.ind_max:
                return print('Compound Evaluation Complete!')
            
    def on_select(self, event):
        with output:
            clear_output()
            selected_index = plot_filenames.index(event)
            self.ind = selected_index
        
            pdf = PDF(plot_files[self.ind], size=pdf_view_size)
            return display(pdf)

# %%
events = Events()
output = widgets.Output()

good_button.on_click(events.good_button_click)
ambiguous_button.on_click(events.ambiguous_button_click)
manual_select_dropdown = interactive(events.on_select, event=compound_drop)

button_container = HBox(layout=Layout(width='100%',display='inline-flex',flex_flow='row wrap', align_items='center'))
button_container.children = [good_button, ambiguous_button, override_filter_button, compound_drop]

display(button_container, output)
# Out:
# HBox(children=(Button(description='Good', style=ButtonStyle(button_color='lightgreen', font_weight='bold')), B…
# Output()

# %% [markdown]
# ## Save 'Good' and 'Ambiguous' Observation Tables

# %%
events.ambiguous_df.to_csv(os.path.join(msms_set_output_ambiguous_dir, 'ambiguous_observation_table.csv'))
events.filtered_good_df.to_csv(os.path.join(msms_set_output_good_dir, 'final_observation_table.csv'))

# %%
events.filtered_good_df
# Out:
#                                          gnps_filename  seq  \
# 292  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 293  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 294  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 295  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
# 296  tharwood/MSMS-Chooser_507992_PlantStds_Set1_QE...  *.*
#
#                                     compound_name  moleculemass instrument  \
# 292   TransZeatinRiboside-tZR-CE102040-10ugmL-M+H    352.161545   Orbitrap
# 293   TransZeatinRiboside-tZR-CE205060-10ugmL-M+H    352.161545   Orbitrap
# 294   TransZeatinRiboside-tZR-CE102040-10ugmL-M-H    350.146993   Orbitrap
# 295  TransZeatinRiboside-tZR-CE102040-10ugmL-2M-H    701.301262   Orbitrap
# 296   TransZeatinRiboside-tZR-CE205060-10ugmL-M-H    350.146993   Orbitrap
#
#     ionsource  extractscan                                             smiles  \
# 292       ESI         1205  C/C(=C\CNC1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@...
# 293       ESI         1208  C/C(=C\CNC1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@...
# 294       ESI         1052  C/C(=C\CNC1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@...
# 295       ESI         1058  C/C(=C\CNC1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@...
# 296       ESI         1049  C/C(=C\CNC1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@...
#
#                                                  inchi  inchiaux  ...  \
# 292  InChI=1S/C15H21N5O5/c1-8(4-21)2-3-16-13-10-14(...       NaN  ...
# 293  InChI=1S/C15H21N5O5/c1-8(4-21)2-3-16-13-10-14(...       NaN  ...
# 294  InChI=1S/C15H21N5O5/c1-8(4-21)2-3-16-13-10-14(...       NaN  ...
# 295  InChI=1S/C15H21N5O5/c1-8(4-21)2-3-16-13-10-14(...       NaN  ...
# 296  InChI=1S/C15H21N5O5/c1-8(4-21)2-3-16-13-10-14(...       NaN  ...
#
#                                        label_msms  \
# 292   TransZeatinRiboside-tZR-CE102040-10ugmL-M+H
# 293   TransZeatinRiboside-tZR-CE205060-10ugmL-M+H
# 294   TransZeatinRiboside-tZR-CE102040-10ugmL-M-H
# 295  TransZeatinRiboside-tZR-CE102040-10ugmL-2M-H
# 296   TransZeatinRiboside-tZR-CE205060-10ugmL-M-H
#
#                                                mz_msms  \
# 292  [52.010066986083984 64.06074523925781 66.17830...
# 293  [55.01809310913086 220.11924743652344 206.3925...
# 294  [53.13127517700195 266.0894470214844 242.03640...
# 295  [53.74528121948242 350.14703369140625 266.0888...
# 296  [65.0140380859375 245.70643615722656 218.10473...
#
#                                                rt_msms  \
# 292  [2.6318588256835938 2.6318588256835938 2.63185...
# 293  [2.626814126968384 2.626814126968384 2.6268141...
# 294  [2.521728038787842 2.521728038787842 2.5217280...
# 295  [2.5326883792877197 2.5326883792877197 2.53268...
# 296  [2.5189545154571533 2.5189545154571533 2.51895...
#
#                                                 i_msms  \
# 292  [8396.6416015625 12588.8466796875 10136.898437...
# 293  [15639.7001953125 1994764.0 11240.9189453125 1...
# 294  [6989.49267578125 2543136.0 6755.1083984375 28...
# 295  [4896.052734375 137035.828125 28498.435546875 ...
# 296  [7608.96728515625 6969.5234375 1452855.0 13657...
#
#                                         label_eic  \
# 292   TransZeatinRiboside-tZR-CE102040-10ugmL-M+H
# 293   TransZeatinRiboside-tZR-CE205060-10ugmL-M+H
# 294   TransZeatinRiboside-tZR-CE102040-10ugmL-M-H
# 295  TransZeatinRiboside-tZR-CE102040-10ugmL-2M-H
# 296   TransZeatinRiboside-tZR-CE205060-10ugmL-M-H
#
#                                                 rt_eic  \
# 292  [2.468604803085327 4.77210807800293 4.73920631...
# 293  [2.4364748001098633 4.365241050720215 4.377738...
# 294  [2.4909067153930664 2.845547914505005 2.838529...
# 295  [2.5116021633148193 2.5195043087005615 2.52496...
# 296  [2.481501817703247 2.736279010772705 2.7433145...
#
#                                                  i_eic  \
# 292  [7550.01708984375 5676.47509765625 7446.319824...
# 293  [5433.06396484375 7089.228515625 7372.49755859...
# 294  [4125.97216796875 4723.74609375 9755.196289062...
# 295  [23753.263671875 277501.3125 622625.0 1001445....
# 296  [2494.300537109375 12945.509765625 15391.12011...
#
#                                         in_feature_eic  filter_override  \
# 292  [False False False False False False False Fal...            False
# 293  [False False False False False False False Fal...            False
# 294  [True False False False False False False Fals...            False
# 295  [True True True True True True True True True ...            False
# 296  [True False False False False False False Fals...            False
#
#                    group
# 292  TransZeatinRiboside
# 293  TransZeatinRiboside
# 294  TransZeatinRiboside
# 295  TransZeatinRiboside
# 296  TransZeatinRiboside
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Compare "Good" Compounds from Both Chromatographies, Display List of "Ambiguous" Compounds In Both

# %%
chromatographies = ['hilic', 'c18'] #list of chromatographies used

good_plot_filenames = []
ambiguous_plot_filenames = []

for ch in chromatographies:
    
    msms_set_output_good_dir = 'downloads/plant_standards_diagnostic_plots_{chromatography}/good'.format(chromatography=ch)
    msms_set_output_ambiguous_dir = 'downloads/plant_standards_diagnostic_plots_{chromatography}/ambiguous'.format(chromatography=ch)
    
    good_plot_files = glob.glob(os.path.join(msms_set_output_good_dir, '*.pdf'))
    
    for f in good_plot_files:
        good_plot_filenames.append(os.path.basename(f))
        
    ambiguous_plot_files = glob.glob(os.path.join(msms_set_output_ambiguous_dir, '*.pdf'))
    
    for f in ambiguous_plot_files:
        ambiguous_plot_filenames.append(os.path.basename(f))

# %%
set(ambiguous_plot_filenames) - set(good_plot_filenames)
# Out:
# {'12HydroxyJasmonicAcid-12-OH-JA.pdf',
#  'Indole3AcetyleGlutamicAcid-IAA-Glu.pdf'}
